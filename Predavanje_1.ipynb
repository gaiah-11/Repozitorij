# %% [markdown]
# <a href="https://colab.research.google.com/github/gaiah-11/Repozitorij/blob/main/Predavanje_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Predavanje

# %%
12
# Out:
# 12

# %%
type(12)
# Out:
# int

# %%
type(12,5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-1465952872.py in <cell line: 0>()
# ----> 1 type(12,5)
#
# TypeError: type() takes 1 or 3 arguments

# %%
type(12.5)
# Out:
# float

# %%
type(Draga)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1204724560.py in <cell line: 0>()
# ----> 1 type(Draga)
#
# NameError: name 'Draga' is not defined

# %%
'apple'
# Out:
# 'apple'

# %%
"apple"
# Out:
# 'apple'

# %%
type(draga)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-236085153.py in <cell line: 0>()
# ----> 1 type(draga)
#
# NameError: name 'draga' is not defined

# %%
False
# Out:
# False

# %%
3=4
# Out:
#   File "/tmp/ipython-input-1436796609.py", line 1
#     3=4
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
dictionaries {}
list []
tuple ()
# Out:
#   File "/tmp/ipython-input-3067695636.py", line 1
#     dictionaries {}
#                  ^
# SyntaxError: invalid syntax

# %%
[1,2,3]
# Out:
# [1, 2, 3]

# %%
type([1,2,3])
# Out:
# list

# %%
1,2,3
# Out:
# (1, 2, 3)

# %%
t = [1,2,3]

# %%
t
# Out:
# [1, 2, 3]

# %%
plants = {"apple": "a fruit", "banana": "a herb"}

# %%
type({"apple": "a fruit", "banana": "a herb"})
# Out:
# dict

# %%
3 < 5
# Out:
# True

# %%
plants['banana']
# Out:
# 'a herb'

# %%
import pandas as pd

# %%
pd.DataFrame(plants, [0,1])
# Out:
#      apple  banana
# 0  a fruit  a herb
# 1  a fruit  a herb

# %%
squares = [1,4,9,16,25]

# %%
type(squares)
# Out:
# list

# %%
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
squares[4]
# Out:
# 25

# %%
squares[-2]
# Out:
# 16

# %%
squares[:]
# Out:
# [1, 4, 9, 16, 25]

# %%
squares[1:]
# Out:
# [4, 9, 16, 25]

# %%
squares[1:3]
# Out:
# [4, 9]

# %%
squares + [36,49,64,81,100]
# Out:
# [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %%
squares
# Out:
# [1, 4, 9, 16, 25]

# %%
sq2 = squares + [36,49,64,81,100]

# %%
animals = ['cat', 'dog', 'bird']

# %%
animals[0]
# Out:
# 'cat'

# %%
len(sq2)
# Out:
# 10

# %%
len(sq2[:5])
# Out:
# 5

# %%
letters = ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letters
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f', 'g']

# %%
letters[1:2] = [1,2,3,4,5]

# %%
letters
# Out:
# ['a', 1, 2, 3, 4, 5, 'c', 'd', 'e', 'f', 'g']

# %%
len(letters)
# Out:
# 11

# %%
abs(1)
# Out:
# 1

# %%
abs(-10)
# Out:
# 10

# %%
import operator

# %%
1 + 3
# Out:
# 4

# %%
operator.add(1,3)
# Out:
# 4

# %%
operator.sub(1,10)
# Out:
# -9

# %%
operator.eq(10,10)
# Out:
# True

# %%
##Print

# %% [markdown]
# ##Print

# %%
print(1)
# Out:
# 1

# %%
print('This'+'' + 'is'+''+'a'+''+'full'+''+'sentence')
# Out:
# Thisisafullsentence

# %%
print('This'+' ' + 'is'+' '+'a'+' '+'full'+' '+'sentence')
# Out:
# This is a full sentence

# %%
print('This', 'is', 'a', 'full', 'sentence')
# Out:
# This is a full sentence

# %%
print('Micheal', 'is', 'helping')
# Out:
# Micheal is helping

# %%
print(sq2[1:5])
# Out:
# [4, 9, 16, 25]

# %%
None

# %%
type(None)
# Out:
# NoneType
