# %% [markdown]
# <a href="https://colab.research.google.com/github/gaiah-11/Repozitorij/blob/main/1_kolab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = (2,3,4)

# %%
n
# Out:
# (2, 3, 4)
